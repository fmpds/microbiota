# %% [markdown]
# # Baixando dados direto do Kaggle

# %% [markdown]
# ### **1º Abra sua conta no Kaggle**
#
# No seu perfil, clique em "Account", e desça até a seção "API". Caso você já tenha criado tokens, clique em "**Expire API token**". Caso contráio, clique em "**Create new API token**". Ao fazer isso, o arquivo *kaggle.json* será baixado em seu computador.
#
# ### **2º Abra o seu projeto no Google Colab**
#
# Em seu notebook, você irá executar os seguintes comandos:
#
#
#
# 1.   ! pip install -q kaggle
# 2.   from google.colab import files
# 3.   files.upload() <- faça o upload do arquivo kaggle.json
# 4.   ! mkdir ~/.kaggle
# 5.   ! cp kaggle.json ~/.kaggle/
# 6.   ! chmod 600 ~/.kaggle/kaggle.json <- mudando permissão do arquivo
#
# Pronto, agora você pode verificar se tudo ocorreu certo executando a seguinte linha de código:
#
# ! kaggle datasets list

# %%
! pip install -q kaggle

# %%
from google.colab import files

# %%
files.upload()

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d antaresnyc/metagenomics
# Out:
# Downloading metagenomics.zip to /content
#  82% 65.0M/79.6M [00:03<00:00, 20.0MB/s]
# 100% 79.6M/79.6M [00:03<00:00, 26.2MB/s]

# %%
! unzip metagenomics.zip
# Out:
# Archive:  metagenomics.zip
#   inflating: abundance.txt
#   inflating: abundance_stoolsubset.txt
#   inflating: marker_presence.txt
#   inflating: markers2clades_DB.txt

# %%
# criando pasta para adicinar os dados baixados
! mkdir Metagenome_data

# %%
# movendo arquivos para pasta
! mv ./*.txt ./Metagenome_data/

# %% [markdown]
# # Python
#
# Seção para manipulação do dataframe.

# %%
import os
import pandas as pd
import numpy as np
import re
from scipy.stats import norm

import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
os.chdir('Metagenome_data/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-808f9cef5e80> in <module>()
# ----> 1 os.chdir('Metagenome_data/')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Metagenome_data/'

# %%
def read_csv(file_name: str) -> pd.core.frame.DataFrame:
  '''
    Function to create and process a dataframe.

    Arguments:
    file_name: str. csv filename

    Returns:
    df: pd.core.frame.Dataframe. dataframe
  '''

  df = pd.read_csv(file_name, sep = '\t', dtype = 'unicode')
  df = df.T
  df.columns = df.iloc[0]
  df.drop(['dataset_name'] , axis = 0, inplace = True)
  
  return df

# %%
df = read_csv('abundance_stoolsubset.txt')
df.head()
# Out:
# dataset_name     sampleID  ... k__Bacteria|p__Firmicutes|c__Negativicutes|o__Selenomonadales|f__Veillonellaceae|g__Megasphaera|s__Megasphaera_sp_BV3C16_1|t__GCF_000478965
# Candela_Africa        H10  ...                                                  0
# Candela_Africa.1      H11  ...                                                  0
# Candela_Africa.2      H12  ...                                                  0
# Candela_Africa.3      H13  ...                                                  0
# Candela_Africa.4      H14  ...                                                  0
#
# [5 rows x 2338 columns]

# %%
df.shape
# Out:
# (1989, 2338)

# %%
columns = df.columns.to_list()

# %%
len(columns)
# Out:
# 2338

# %%
def Find(pattern:str, txt:str) -> str:
  '''
    Função para buscar padrao em string. Se o padrao eh encontrado, retorna padrao.


    Argumentos:
    pattern: str. padrao procurado.
    txt: str. string onde o padrao sera procurado

    Return:
    match.group(): str ou None. Se encontrar padrao, retorna padrao, caso contrario
    None.
  '''

  match = re.search(pattern, txt)

  if match: return match.group()

# %%
# buscando todas as colunas do reino bacteria
column_names = [s for i, s in enumerate(columns) if 'k__Bacteria' in s]

# %%
# buscando apenas as colunas que representam os generos
genero_names = []

# demora um pouquinho

for i in range(len(column_names)):
  aux = Find(r'\w+.\w+.\w+.\w+.\w+.g__\w+$', column_names[i])
  if aux != None:
    genero_names.append(aux)

# %%
genero_names.insert(0, 'disease')

# %%
# recolhendo colunas de interesse
df_genus_disease = df.loc[: , genero_names]

# %%
df_genus_disease.to_csv("df_genus_disease.csv")

# %%
df_genus_disease = pd.read_csv('df_genus_disease.csv')
df_genus_disease.head()
# Out:
#          Unnamed: 0  ... k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Peptococcaceae|g__Desulfotomaculum
# 0    Candela_Africa  ...                                                0.0
# 1  Candela_Africa.1  ...                                                0.0
# 2  Candela_Africa.2  ...                                                0.0
# 3  Candela_Africa.3  ...                                                0.0
# 4  Candela_Africa.4  ...                                                0.0
#
# [5 rows x 272 columns]

# %%
df_genus_disease.rename(columns = {'Unnamed: 0' : 'dataset_name'}, inplace = True)
df_genus_disease.head()
# Out:
#        dataset_name  ... k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Peptococcaceae|g__Desulfotomaculum
# 0    Candela_Africa  ...                                                0.0
# 1  Candela_Africa.1  ...                                                0.0
# 2  Candela_Africa.2  ...                                                0.0
# 3  Candela_Africa.3  ...                                                0.0
# 4  Candela_Africa.4  ...                                                0.0
#
# [5 rows x 272 columns]

# %%
df_genus_disease.drop(['dataset_name'], axis = 1, inplace = True)
df_genus_disease.head()
# Out:
#   disease  ...  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Peptococcaceae|g__Desulfotomaculum
# 0       n  ...                                                0.0
# 1       n  ...                                                0.0
# 2       n  ...                                                0.0
# 3       n  ...                                                0.0
# 4       n  ...                                                0.0
#
# [5 rows x 271 columns]

# %%
df_genus_disease.columns

# %%
df_genus_disease.to_csv("df_individual.csv")

# %%
df_genus = df_genus_disease

# %%
df_genus['dataset_name'].value_counts()
# Out:
# t2dmeta_long.125               1
# Quin_gut_liver_cirrhosis.74    1
# Chatelier_gut_obesity.159      1
# Chatelier_gut_obesity.197      1
# Neilsen_genome_assembly.337    1
#                               ..
# Tito_subsistence_gut.10        1
# t2dmeta_long.41                1
# WT2D.84                        1
# Chatelier_gut_obesity.225      1
# t2dmeta_short.31               1
# Name: dataset_name, Length: 1989, dtype: int64

# %%
df_age = df_subset[(df_subset['age'] != 'nd') & (df_subset['age'] != 'na') & (df_subset['age'] != ' -')]
df_age.head()
# Out:
# dataset_name     disease age  gender
# Candela_Africa         n  40  female
# Candela_Africa.1       n  29  female
# Candela_Africa.2       n   8  female
# Candela_Africa.3       n  34    male
# Candela_Africa.4       n  30    male

# %%
age_list = np.asarray(df_age['age'], dtype = 'float')

# %%
# modelando nossos dados - encontrando média e desvio padrao
mu, std = norm.fit(age_list)

# plot do histograma
plt.figure(figsize = (18, 10))
plt.hist(age_list, bins = 500, density = True, alpha = 0.6, color='g')

# plot função de densidade de probabilidades
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)

# parametros graficos
plt.plot(x, p, 'k', linewidth = 2)
title = "Média = %.2f e  Desvio Padrão = %.2f das idades" % (mu, std)
plt.title(title, fontsize = 18)

plt.show()

# %%
df_genus_disease.head()
# Out:
#   disease  ...  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Peptococcaceae|g__Desulfotomaculum
# 0       n  ...                                                0.0
# 1       n  ...                                                0.0
# 2       n  ...                                                0.0
# 3       n  ...                                                0.0
# 4       n  ...                                                0.0
#
# [5 rows x 271 columns]

# %%
df = df_genus_disease.groupby(['disease'], as_index = False).mean()

# %%
df = df[(df['disease'] != 'small_adenoma') & (df['disease'] != 'ibd_crohn_disease') & (df['disease'] != ' -') & (df['disease'] != 'large_adenoma') & (df['disease'] != 'overweight') & (df['disease'] != 'obese') & (df['disease'] != 'underweight')]

# %%
values = df['disease'].tolist()

# %%
values
# Out:
# ['cancer',
#  'cirrhosis',
#  'ibd_ulcerative_colitis',
#  'impaired_glucose_tolerance',
#  'leaness',
#  'n',
#  'n_relative',
#  'obesity',
#  'stec2-positive',
#  't2d']

# %%
df
# Out:
#                        disease  ...  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clostridiales|f__Peptococcaceae|g__Desulfotomaculum
# 2                       cancer  ...                                           0.001669
# 3                    cirrhosis  ...                                           0.000000
# 5       ibd_ulcerative_colitis  ...                                           0.000000
# 6   impaired_glucose_tolerance  ...                                           0.000000
# 8                      leaness  ...                                           0.000000
# 9                            n  ...                                           0.000000
# 10                  n_relative  ...                                           0.000000
# 12                     obesity  ...                                           0.000000
# 15              stec2-positive  ...                                           0.000000
# 16                         t2d  ...                                           0.000000
#
# [10 rows x 271 columns]

# %%
s = df.sum(axis=0, numeric_only=True)

# %%
df[s.sort_values(ascending=False).index[:30]]
# Out:
#     k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o__Bacteroidales|f__Bacteroidaceae|g__Bacteroides  ...  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Lactobacillaceae|g__Lactobacillus
# 2                                           20.537735                                              ...                                           0.142701
# 3                                           29.296794                                              ...                                           1.603171
# 5                                           21.158290                                              ...                                           0.382696
# 6                                            9.427734                                              ...                                           0.388741
# 8                                           18.249164                                              ...                                           0.030545
# 9                                           30.599845                                              ...                                           0.128924
# 10                                          23.601274                                              ...                                           0.507920
# 12                                          20.040463                                              ...                                           0.080937
# 15                                          20.955047                                              ...                                           0.141377
# 16                                          26.951813                                              ...                                           1.156481
#
# [10 rows x 30 columns]

# %%
df = df[s.sort_values(ascending=False).index[:30]]

# %%
df.insert(loc = 0, column = 'disease', value=values)
df
# Out:
#                   dataset_name  ...  k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Lactobacillaceae|g__Lactobacillus
# 2                       cancer  ...                                           0.142701
# 3                    cirrhosis  ...                                           1.603171
# 5       ibd_ulcerative_colitis  ...                                           0.382696
# 6   impaired_glucose_tolerance  ...                                           0.388741
# 8                      leaness  ...                                           0.030545
# 9                            n  ...                                           0.128924
# 10                  n_relative  ...                                           0.507920
# 12                     obesity  ...                                           0.080937
# 15              stec2-positive  ...                                           0.141377
# 16                         t2d  ...                                           1.156481
#
# [10 rows x 31 columns]

# %%
columns = []

for i in range(1, len(df.columns)):
  aux = re.split(r'\w+.\w+.\w+.\w+.\w+.g__', df.columns[i])
  columns.append(aux[1])

# %%
columns.insert(0, 'disease')

# %%
df.columns = columns

# %%
df
# Out:
#                        disease  Bacteroides  ...  Paraprevotella  Lactobacillus
# 2                       cancer    20.537735  ...        0.203869       0.142701
# 3                    cirrhosis    29.296794  ...        0.260237       1.603171
# 5       ibd_ulcerative_colitis    21.158290  ...        0.526609       0.382696
# 6   impaired_glucose_tolerance     9.427734  ...        0.197059       0.388741
# 8                      leaness    18.249164  ...        1.092853       0.030545
# 9                            n    30.599845  ...        0.684335       0.128924
# 10                  n_relative    23.601274  ...        0.634814       0.507920
# 12                     obesity    20.040463  ...        1.224662       0.080937
# 15              stec2-positive    20.955047  ...        0.020717       0.141377
# 16                         t2d    26.951813  ...        0.373652       1.156481
#
# [10 rows x 31 columns]

# %%
df.to_csv('df_genus_disease.csv')

# %% [markdown]
# # Big data

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
import pyspark

def spark_shape(self):
    '''
      Funcao para visualizar o shape do dataframe.

      Retorno:
      count -- numero de linhas
      columns -- numero de colunas
    '''
    return (self.count(), len(self.columns))


pyspark.sql.dataframe.DataFrame.shape = spark_shape

# %%
from pyspark.sql.functions import col, concat_ws, collect_list

def TransposeDF(df, columns, pivotCol):

    columnsValue = list(map(lambda x: str("'") + str(x) + str("',")  + str(x), columns))
    stackCols = ','.join(x for x in columnsValue)
    df_1 = df.selectExpr(pivotCol, "stack(" + str(len(columns)) + "," + stackCols + ")")\
             .select(pivotCol, "col0", "col1")
    final_df = df_1.groupBy(col("col0")).pivot(pivotCol).agg(concat_ws("", collect_list(col("col1"))))\
                   .withColumnRenamed("col0", pivotCol)
    
    return final_df

# %%
.conf.set('spark.sql.pivotMaxValues', u'')

# %%
spark.conf.set('spark.sql.pivotMaxValues', u'288558')

# %%
df = spark.read.load("marker_presence.txt", format = 'csv', header = True, sep = '\t')

# %%
df.show()
# Out:
# +--------------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+-- ...
# |        dataset_name|Candela_Africa1|Candela_Africa2|Candela_Africa3|Candela_Africa4|Candela_Africa5|Candela_Africa6|Candela_Africa7|Candela_Africa8|Candela_Africa9|Candela_Africa10|Candela_Africa11|Candela_Africa12|Candela_Africa13|Candela_Africa14|Candela_Africa15|Candela_Africa16|Candela_Africa17|Candela_Africa18|Candela_Africa19|Candela_Africa20|Candela_Africa21|Candela_Africa22|Candela_Africa23|Candela_Africa24|Candela_Africa25|Candela_Africa26|Candela_Africa27|Candela_Africa28|Candela_Africa29|Candela_Africa30|Candela_Africa31|Candela_Africa32|Candela_Africa33|Candela_Africa34|Candela_Africa35|Candela_Africa36|Candela_Africa37|Candela_Africa38|Chatelier_gut_obesity39|Chatelier_gut_obesity40|Chatelier_gut_obesity41|Chatelier_gut_obesity42|Chatelier_gut_obesity43|Chatelier_gut_obesity44|Chatelier_gut_obesity45|Chatelier_gut_obesity46|Chatelier_gut_obesity47|Chatelier_gut_obesity48|Chatelier_gut_obesity49|Chatelier_gut_obesity50|Chatelier_gut_obesity51|Chatelier_gut_obesity52|Chatelier_gut_obesity53|Chatelier_gut_obesity54|Chatelier
                 obesity|                 obesity|                 obesity|                 obesity|                 obesity|                 obesity|                 obesity|                 obesity|                 obesity|                 leaness|                 leaness|                 obesity|                 obesity|                       n|                 obesity|                 obesity|                 leaness|                 leaness|                 obesity|                 leaness|                 obesity|                 obesity|                 obesity|                       n|                 obesity|                 obesity|                       n|                       n|                 obesity|                       n|                       n|                 obesity|                 obesity|                 leaness|                 obesity|                 leaness|                 obesity|   ...
# |                 age|             40|             29|              8|             34|             30|             16|             21|             23|             17|              15|              43|              13|              43|              38|              24|              65|              40|              48|              29|              37|              22|              24|              70|              30|              38|              20|              47|              40|              30|              21|              38|              34|              29|              27|              30|              32|              25|              34|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                     nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|                      nd|   ...
# |              gender|         female|         female|         female|           male|           male|           male|           male|           male|           male|            male|          female|            male|            male|            male|            male|            male|            male|            male|          female|            male|            male|            male|          female|            male|          female|          female|          female|          female|          female|          female|            male|          female|          female|            male|            male|          female|          female|            male|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                      -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|                       -|   ...
# |             country|       tanzania|       tanzania|       tanzania|       tanzania|       tanzania|       tanzania|       tanzania|       tanzania|       tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|        tanzania|           italy|           italy|           italy|           italy|           italy|           italy|           italy|           italy|           italy|           italy|           italy|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|                 denmark|   ...
# |sequencing_techno...|       Illumina|       Illumina|       Illumina|       Illumina|       Illumina|       Illumina|       Illumina|       Illumina|       Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|        Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|               Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|                Illumina|   ...
# ...
# |hitchip_probe_number|             nd|             nd|             nd|             nd|             nd|             nd|             nd|             nd|             nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|                   1421|                   1182|                   1234|                   1550|                   1366|                   1207|                   1438|                   1302|                    970|                   1523|                   1358|                   1432|                   1395|                   1368|                   1184|                   1332|                   1233|                   1221|                    955|                   1476|                   1350|                   1250|                   1353|                   1461|                   1521|                   1370|                   1481|                   1315|                   1242|                   1321|                   1265|                   1178|                   1554|                   1114|                   1559|                   1388|                   1459|                   1495|                   1300|                   1404|                   1596|                   1263|                   1448|                   1498|                   1413|                    915|                   1166|                   1374|                   1403|                   1378|                   1283|                   1074|                   1056|                   1387|                   1519|                   1470|                   1048|                   1096|                    911|                   1337|                   1310|                    1505|                    1086|                    1251|                    1471|                    1249|                    1419|                    1262|                    1197|                    1214|                    1392|                     712|                    1027|                    1153|                    1465|                    1276|                    1253|                    1021|                    1239|                    1430|                    1258|                    1428|                    1405|                    1286|                    1453|                    1159|                    1355|                    1301|                    1440|                    1321|                    1211|                    1332|                    1081|                     995|                     972|                    1243|                    1393|                    1033|                    1317|                    1326|                    1531|                    1650|                    1523|                    1556|                    1187|                    1059|                    1308|                    1454|                    1213|                    1246|                    1208|                    1022|                    1303|                    1251|                    1246|                    1352|                    1044|                    1167|                    1348|                    1019|                    1068|                    1003|                    1187|                    1280|                    1101|                     903|                    1398|                    1426|                    1313|                    1372|                    1209|                    1369|                    1271|                    1275|                    1410|                    1324|   ...
# |                 bmi|             nd|             nd|             nd|             nd|             nd|             nd|             nd|             nd|             nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|              nd|                   27.3|                   33.2|                   22.4|                     29|                   22.3|                   32.1|                   38.5|                   30.5|                   33.2|                   25.4|                   22.7|                   34.2|                   37.3|                   22.7|                   35.2|                   22.3|                   35.3|                     32|                     40|                   22.7|                   30.7|                     24|                     22|                   23.1|                   20.9|                   23.2|                   24.5|                   23.7|                   24.5|                   25.1|                   23.7|                   30.4|                   19.4|                   35.5|                   25.1|                   23.2|                   33.2|                   32.7|                   20.3|                   30.3|                   25.3|                     33|                     22|                   33.3|                   23.5|                     30|                   37.5|                   30.2|                   23.2|                   28.2|                   20.8|                   21.1|                     29|                   36.7|                   22.7|                   25.4|                   40.2|                   32.5|                   20.5|                   30.6|                   34.8|                    24.9|                    36.9|                      20|                    18.6|                      38|                    22.6|                    30.6|                    31.7|                    36.5|                    21.6|                      23|                    31.6|                    22.5|                    28.2|                    31.1|                    35.5|                    34.5|                    33.5|                    38.7|                    40.2|                    34.7|                    23.9|                    32.4|                    30.2|                    32.3|                    31.3|                      30|                    28.9|                    32.5|                    30.1|                    19.6|                      34|                    29.6|                    31.6|                    31.1|                    23.1|                    31.4|                    23.9|                    30.9|                      34|                    31.5|                    42.9|                    30.7|                    35.1|                    30.5|                    31.5|                    33.7|                    22.1|                    21.2|                    32.3|                    36.5|                    28.9|                    33.3|                    31.2|                      24|                    22.7|                    32.1|                    22.6|                    30.9|                    30.2|                    31.1|                    27.6|                    31.3|                    30.5|                    29.4|                    28.7|                    30.9|                    25.7|                    25.7|                    35.9|                      42|                    22.4|                    36.6|                      23|                    34.6|   ...
# +--------------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+---------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+----------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+-----------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+------------------------+-- ...
# only showing top 20 rows

# %%
df.limit(10).toPandas().T
# Out:
#                                                      0  ...        9
# dataset_name                                  sampleID  ...     camp
# Candela_Africa1                                    H10  ...  dedauko
# Candela_Africa2                                    H11  ...  dedauko
# Candela_Africa3                                    H12  ...  dedauko
# Candela_Africa4                                    H13  ...  dedauko
# ...                                                ...  ...      ...
# Zeller_fecal_colorectal_cancer3606  CCIS95409808ST-4-0  ...       nd
# Zeller_fecal_colorectal_cancer3607  CCIS96387239ST-4-0  ...       nd
# Zeller_fecal_colorectal_cancer3608  CCIS98482370ST-3-0  ...       nd
# Zeller_fecal_colorectal_cancer3609  CCIS98512455ST-4-0  ...       nd
# Zeller_fecal_colorectal_cancer3610  CCIS98832363ST-4-0  ...       nd
#
# [3611 rows x 10 columns]

# %%
df.shape()
# Out:
# (288557, 3611)

# %%
columns_names = df.schema.names

# %%
columns_names.remove('dataset_name')

# %%
columns_names

# %%
df = TransposeDF(df, columns = columns_names, pivotCol = 'dataset_name')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-21-b006cceb1ca6> in <module>()
# ----> 1 df = TransposeDF(df, columns = columns_names, pivotCol = 'dataset_name')
#
# <ipython-input-20-d10a8a08114d> in TransposeDF(df, columns, pivotCol)
#       6     stackCols = ','.join(x for x in columnsValue)
#       7     df_1 = df.selectExpr(pivotCol, "stack(" + str(len(columns)) + "," + stackCols + ")")             .select(pivotCol, "col0", "col1")
# ----> 8     final_df = df_1.groupBy(col("col0")).pivot(pivotCol).agg(concat_ws("", collect_list(col("col1"))))                   .withColumnRenamed("col0", pivotCol)
#       9
#      10     return final_df
#
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/group.py in agg(self, *exprs)
#     117             assert all(isinstance(c, Column) for c in exprs), "all exprs should be Column"
#     118             jdf = self._jgd.agg(exprs[0]._jc,
# --> 119                                 _to_seq(self.sql_ctx._sc, [c._jc for c in exprs[1:]]))
#     120         return DataFrame(jdf, self.sql_ctx)
#     121
#
# /usr/local/lib/python3.7/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#    1307         for temp_arg in temp_args:
#
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     109     def deco(*a, **kw):
#     110         try:
# --> 111             return f(*a, **kw)
#     112         except py4j.protocol.Py4JJavaError as e:
#     113             converted = convert_exception(e.java_exception)
#
# /usr/local/lib/python3.7/dist-packages/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o97.agg.
# : java.lang.OutOfMemoryError: Java heap space

# %%
os.listdir()
# Out:
# ['.config',
#  'kaggle (1).json',
#  'abundance.txt',
#  'markers2clades_DB.txt',
#  'abundance_stoolsubset.txt',
#  'kaggle.json',
#  'metagenomics.zip',
#  'Metagenome_data',
#  'marker_presence.txt',
#  'sample_data']

# %%
abundance = pd.read_csv("abundance.txt", sep = '\t', dtype = 'unicode').T

abundance.head()
# Out:
#   dataset_name  ... Zeller_fecal_colorectal_cancer.133
# 0     sampleID  ...                 CCIS98832363ST-4-0
# 1    subjectID  ...                             fr-552
# 2     bodysite  ...                              stool
# 3      disease  ...                             cancer
# 4          age  ...                                 55
#
# [5 rows x 3611 columns]

# %%
marker_presence = pd.read_csv("marker_presence.txt", sep = '\t')

marker_presence.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-95d4fb449606> in <module>()
# ----> 1 marker_presence = pd.read_csv("marker_presence.txt", sep = '\t')
#       2
#       3 marker_presence.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     528
#     529
# --> 530 def is_categorical_dtype(arr_or_dtype) -> bool:
#     531     """
#     532     Check whether an array-like or dtype is of the Categorical dtype.
#
# KeyboardInterrupt:

# %%
abundance_stoolsubset = pd.read_csv('abundance_stoolsubset.txt', sep = '\t', dtype = 'unicode')

abundance_stoolsubset.head()
# Out:
#   dataset_name  ... Zeller_fecal_colorectal_cancer.133
# 0     sampleID  ...                 CCIS98832363ST-4-0
# 1    subjectID  ...                             fr-552
# 2     bodysite  ...                              stool
# 3      disease  ...                             cancer
# 4          age  ...                                 55
#
# [5 rows x 1990 columns]

# %% [markdown]
# # R

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# #install.packages("hrbrthemes", repos = c("https://cinc.rud.is", "https://cloud.r-project.org/"))
# library(ggplot2)
# #library(hrbrthemes)
# library(tidyr)
# #install.packages("hrbrthemes")

# %%
# %%R
#
# # colors
# color_pallete30 <-  c("#5C9476","#25a696", "#43d6c5", "#96e8df", "#5100D6", "#08519C", "#3182BD", "#6BAED6", "#BDD7E7", "#b30024", "#ff0033", "#ff554d" ,"#ff9e99",
#                       "#FAE819", "#FFEC8B", "#FECC5C", "#fe9a4d", "#fe6f01", "#ccccb3", "#adad85", "#999966", "#C2E699", "#78C679" ,"#31A354", "#006837", "#810F7C", "#ac39ac", "#cc66cc",  "#C781D4", "#ffb3ff"
#                     )
#
#
# color_pallete20 <-  c("#31A354", "#006837", "#810F7C", "#ac39ac", "#cc66cc","#25a696", "#43d6c5", "#96e8df", "#08519C", "#3182BD", "#6BAED6", "#BDD7E7", "#b30024", "#ff0033", "#ff554d" ,"#ff9e99",
#                     "#FFEC8B", "#FECC5C", "#fe9a4d", "#fe6f01", "#C2E699", "#78C679", "#ffb3ff", "#ccccb3", "#adad85", "#999966"
# )
# color_pallete10 <- c("#08519C", "#BDD7E7", "#ff0033", "#ff9e99",  "#fe9a4d", "#78C679", "#810F7C",  "#FECC5C", "#25a696", "#006837")

# %%
# %%R
#
# install.packages("dendextend")
# library(dendextend)
# library(tibble)
#
# install.packages("pvclust")
# library(pvclust)

# %%
# %%R
#
# #install.packages('cowplot')
# library(cowplot)

# %%
import os

os.chdir('Metagenome_data/')

# %%
# %%R
#
# # dendogram + barplot
# df <- read.csv('df_genus_disease.csv')
# df$X <- NULL
# df_1 <- df %>%
#   column_to_rownames('disease')
#
# data <- df %>%
#   pivot_longer(!disease, names_to = "genus", values_to = "abs_values")

# %%
# %%R
#
# clu <- pvclust(t(df_1), method.hclust = 'ward.D2', method.dist = 'manhattan', nboot = 10)
# Out:
# Bootstrap (r = 0.5)... Done.
# Bootstrap (r = 0.6)... Done.
# Bootstrap (r = 0.7)... Done.
# Bootstrap (r = 0.8)... Done.
# Bootstrap (r = 0.9)... Done.
# Bootstrap (r = 1.0)... Done.
# Bootstrap (r = 1.1)... Done.
# Bootstrap (r = 1.2)... Done.
# Bootstrap (r = 1.3)... Done.
# Bootstrap (r = 1.4)... Done.

# %%
# %%R
#
# dendo <- as.dendrogram(clu)
# data$disease <- factor(data$disease, levels = labels(dendo))

# %%
# %%R
#
# p1 <- ggplot(dendo, horiz = T)
#
# p2 <- ggplot(data, aes(fill=genus, y=abs_values, x=disease)) +
#   geom_bar(position="stack", stat="identity", show.legend = FALSE) + coord_flip() +
#   theme(
#     axis.text.x = element_text(
#       angle = 45,
#       hjust = 1.0,
#       vjust = 1.2
#     )) +   theme(legend.key.size = unit(0.6, 'cm')) +
#   theme(
#     plot.title = element_text(color="black", size=16, hjust = 0.5),
#     axis.title.x = element_text(color="black", size=14, hjust = 0.5),
#     axis.title.y = element_text(color="black", size=14, hjust = 0.5)
#   )+ labs(title="Barplot - 30 genus")  +
#   scale_fill_manual(values=c(color_pallete30))
#
# plot_dendo <- plot_grid(p1, p2, align = 'h')
# plot_dendo
#
# ggsave(filename = "disease.png", plot=plot_dendo, width=12, height = 8, dpi = 600)

# %%
! ls
# Out:
# kaggle.json  Metagenome_data  metagenomics.zip	pca10.csv  sample_data

# %%
# %%R
#
# # read
# df <- read.csv('./pca10.csv')
#
# # pca
# plot <- ggplot(df, aes(x = pca1, y = pca2, color = sample)) +
#   geom_point(size = 6) +
#   labs(title="Principal Component Analysis - 10 Species by age",
#         x ="Component 1", y = "Component 2") +
#    theme(
#     plot.title = element_text(color="black", size=16, hjust = 0.5),
#     axis.title.x = element_text(color="black", size=14, hjust = 0.5),
#     axis.title.y = element_text(color="black", size=14, hjust = 0.5)
#   )+
#   theme(legend.key.size = unit(0.2, 'cm'))
#
# plot
# # save
# #ggsave(filename = "./pca10_age.png", plot = plot, width = 12, height = 8)
